# %%
import sys
import os
import glob as gb
sys.path.append('/home/cbenitez/')
import MTmp as mt
import matplotlib.pyplot as plt
import numpy as np
import oort_cons as oc
# Out:
# WARNING : Can't import Image module...
# amrviewer GUI ImportError : are WxPython and PyTables correctly installed?

# %%
cd $mt.basedir
# Out:
# /fs/nas14/other0/gilgo/gould_belt/patch_geom_amr/vertical

# %%
cd ..
# Out:
# /fs/nas14/other0/gilgo/gould_belt/patch_geom_amr

# %%
ls
# Out:
# 47pc/  circular/  circular-8.0kpc/  pymses_4.0.0/  vertical/

# %%
cd circular/
# Out:
# /fs/nas14/other0/gilgo/gould_belt/patch_geom_amr/circular

# %%
mt.basedir = "/fs/nas14/other0/gilgo/gould_belt/patch_geom_amr/47pc/"

# %% [markdown]
# _____

# %%
mt.basedir
# Out:
# '/fs/nas14/other0/gilgo/gould_belt/patch_geom_amr/47pc/'

# %%
op20 = mt.rop(op=20,limits=(0.6,.85,0.25,0.5,0.375,0.625))
# Out:
# Computing hilbert minimal domain description for output 20 ...
# Done !
# ...
#
#  Succesfully read the output file 20.
#
# Computing hilbert minimal domain description for output 21 ...
# Done !
# ...

# %%
op1 = mt.rop(op=1,limits=(0.6,.85,0.25,0.5,0.375,0.625))
# Out:
# Computing hilbert minimal domain description for output 1 ...
# Done !
# ...
#
#  Succesfully read the output file 1.
#
# Computing hilbert minimal domain description for output 2 ...
# Done !
# ...

# %%
op15 = mt.rop(op=15,limits=(0.6,.85,0.25,0.5,0.375,0.625))
# Out:
# Computing hilbert minimal domain description for output 15 ...
# Done !
# ...
#
#  Succesfully read the output file 15.
#
# Computing hilbert minimal domain description for output 16 ...
# Done !
# ...

# %%
opc = op15
mt.imshow(opc.dd[opc.nz/2-1,:,:],figsize=(8,8),xlab="$X$  [kpc]",ylab="$Y$  [kpc]",zlab=r"$n$ [cm$^{-3}$]",extentto=(opc.x_min,opc.x_max,opc.y_min,opc.y_max),logscale=True,colorbar=True)

# %%
opc1=op15
mt.imshow(opc.dd[:,opc.ny/2-25,:],figsize=(8,8),xlab="$X$  [kpc]",ylab="$Y$  [kpc]",zlab=r"$n$ [cm$^{-3}$]",extentto=(opc.x_min,opc.x_max,opc.y_min,opc.y_max),logscale=True,colorbar=True)

# %%
delta_grid = opc.xx[1]-opc.xx[0]

# %%
opc=op15
mt.imshow(sum(opc.dd[zc,:,:] for zc in range(len(opc.zz)))*delta_grid*mt.C.kpc.express(mt.C.cm),figsize=(8,8),xlab="$X$  [kpc]",ylab="$Y$  [kpc]",zlab=r"$n$ [cm$^{-3}$]",extentto=(opc.x_min,opc.x_max,opc.y_min,opc.y_max),logscale=False,colorbar=True)
