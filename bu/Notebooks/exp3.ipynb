# %%
import sys
import os
import glob as gb
sys.path.append('/home/cbenitez/')
import MTmp as mt
import matplotlib.pyplot as plt
import numpy as np
import oort_cons as oc
# Out:
# WARNING : Can't import Image module...
# amrviewer GUI ImportError : are WxPython and PyTables correctly installed?

# %%
cd /fs/nas14/other0/cbenitez/evolsOC/
# Out:
# /fs/nas14/other0/cbenitez/evolsOC

# %% [markdown]
# ### Experimento 3

# %%
ls
# Out:
# evols_era_cons_go.npy              gra_AvsC_quiv_5.pdf   gra_BvsC_quiv_9.pdf
# evols_era_go.npy                   gra_AvsC_quiv_6.pdf   gra_BvsK_quiv_0.pdf
# evols_exp_central.npy              gra_AvsC_quiv_7.pdf   gra_BvsK_quiv_10.pdf
# evols_exp_central_vels_adi.npy     gra_AvsC_quiv_8.pdf   gra_BvsK_quiv_1.pdf
# evols_oc_var2_bo.npy               gra_AvsC_quiv_9.pdf   gra_BvsK_quiv_2.pdf
# evols_oc_var2_cons_bo.npy          gra_AvsK_quiv_0.pdf   gra_BvsK_quiv_3.pdf
# evols_oc_var2_cons_go.npy          gra_AvsK_quiv_10.pdf  gra_BvsK_quiv_4.pdf
# evols_oc_var2_go.npy               gra_AvsK_quiv_1.pdf   gra_BvsK_quiv_5.pdf
# evols_r_axisim_rp1p2p3p4p5p10.npy  gra_AvsK_quiv_2.pdf   gra_BvsK_quiv_6.pdf
# gra_AvsB_quiv_0.pdf                gra_AvsK_quiv_3.pdf   gra_BvsK_quiv_7.pdf
# gra_AvsB_quiv_10.pdf               gra_AvsK_quiv_4.pdf   gra_BvsK_quiv_8.pdf
# gra_AvsB_quiv_1.pdf                gra_AvsK_quiv_5.pdf   gra_BvsK_quiv_9.pdf
# gra_AvsB_quiv_2.pdf                gra_AvsK_quiv_6.pdf   gra_CvsK_quiv_0.pdf
# gra_AvsB_quiv_3.pdf                gra_AvsK_quiv_7.pdf   gra_CvsK_quiv_10.pdf
# gra_AvsB_quiv_4.pdf                gra_AvsK_quiv_8.pdf   gra_CvsK_quiv_1.pdf
# gra_AvsB_quiv_5.pdf                gra_AvsK_quiv_9.pdf   gra_CvsK_quiv_2.pdf
# gra_AvsB_quiv_6.pdf                gra_BvsC_quiv_0.pdf   gra_CvsK_quiv_3.pdf
# gra_AvsB_quiv_7.pdf                gra_BvsC_quiv_10.pdf  gra_CvsK_quiv_4.pdf
# gra_AvsB_quiv_8.pdf                gra_BvsC_quiv_1.pdf   gra_CvsK_quiv_5.pdf
# gra_AvsB_quiv_9.pdf                gra_BvsC_quiv_2.pdf   gra_CvsK_quiv_6.pdf
# gra_AvsC_quiv_0.pdf                gra_BvsC_quiv_3.pdf   gra_CvsK_quiv_7.pdf
# gra_AvsC_quiv_10.pdf               gra_BvsC_quiv_4.pdf   gra_CvsK_quiv_8.pdf
# gra_AvsC_quiv_1.pdf                gra_BvsC_quiv_5.pdf   gra_CvsK_quiv_9.pdf
# gra_AvsC_quiv_2.pdf                gra_BvsC_quiv_6.pdf   MCMCruns/
# gra_AvsC_quiv_3.pdf                gra_BvsC_quiv_7.pdf
# gra_AvsC_quiv_4.pdf                gra_BvsC_quiv_8.pdf

# %%
varOC_dir = "/fs/nas14/other0/cbenitez/evolsOC/"
exp3 = [np.load(varOC_dir+"evols_era_cons_go.npy"),np.load(varOC_dir+"evols_era_go.npy")]

# %%
np.shape(exp3[0]),np.shape(exp3[1][0]),np.shape(exp3[1][1])
# Out:
# ((81, 2), (11, 6), (81, 11, 120, 6))

# %%
vvcc,lsrs,parts = exp3[0],exp3[1][0],exp3[1][1]

# %%
auxtt2 = np.linspace(-np.pi,np.pi,200)
auxtt = np.linspace(np.pi/4,-np.pi/2,500)

# %%
vvcc
# Out:
# array([[-6. , -6. ],
#        [-6. , -4.5],
#        [-6. , -3. ],
#        [-6. , -1.5],
#        [-6. ,  0. ],
#        [-6. ,  1.5],
#        [-6. ,  3. ],
#        [-6. ,  4.5],
#        [-6. ,  6. ],
#        [-4.5, -6. ],
#        [-4.5, -4.5],
#        [-4.5, -3. ],
#        [-4.5, -1.5],
#        [-4.5,  0. ],
#        [-4.5,  1.5],
#        [-4.5,  3. ],
#        [-4.5,  4.5],
#        [-4.5,  6. ],
#        [-3. , -6. ],
#        [-3. , -4.5],
#        [-3. , -3. ],
#        [-3. , -1.5],
#        [-3. ,  0. ],
#        [-3. ,  1.5],
#        [-3. ,  3. ],
#        [-3. ,  4.5],
#        [-3. ,  6. ],
#        [-1.5, -6. ],
#        [-1.5, -4.5],
#        [-1.5, -3. ],
#        [-1.5, -1.5],
#        [-1.5,  0. ],
#        [-1.5,  1.5],
#        [-1.5,  3. ],
#        [-1.5,  4.5],
#        [-1.5,  6. ],
#        [ 0. , -6. ],
#        [ 0. , -4.5],
#        [ 0. , -3. ],
#        [ 0. , -1.5],
#        [ 0. ,  0. ],
#        [ 0. ,  1.5],
#        [ 0. ,  3. ],
#        [ 0. ,  4.5],
#        [ 0. ,  6. ],
#        [ 1.5, -6. ],
#        [ 1.5, -4.5],
#        [ 1.5, -3. ],
#        [ 1.5, -1.5],
#        [ 1.5,  0. ],
#        [ 1.5,  1.5],
#        [ 1.5,  3. ],
#        [ 1.5,  4.5],
#        [ 1.5,  6. ],
#        [ 3. , -6. ],
#        [ 3. , -4.5],
#        [ 3. , -3. ],
#        [ 3. , -1.5],
#        [ 3. ,  0. ],
#        [ 3. ,  1.5],
#        [ 3. ,  3. ],
#        [ 3. ,  4.5],
#        [ 3. ,  6. ],
#        [ 4.5, -6. ],
#        [ 4.5, -4.5],
#        [ 4.5, -3. ],
#        [ 4.5, -1.5],
#        [ 4.5,  0. ],
#        [ 4.5,  1.5],
#        [ 4.5,  3. ],
#        [ 4.5,  4.5],
#        [ 4.5,  6. ],
#        [ 6. , -6. ],
#        [ 6. , -4.5],
#        [ 6. , -3. ],
#        [ 6. , -1.5],
#        [ 6. ,  0. ],
#        [ 6. ,  1.5],
#        [ 6. ,  3. ],
#        [ 6. ,  4.5],
#        [ 6. ,  6. ]])

# %%
ivc = 35
vv_adi = vvcc[ivc]
print vv_adi
# Out:
# [-1.5  6. ]

# %%
fig, axes = plt.subplots(2, 2,figsize=(8,8))

R0 = 8.0
ivc = 76
ic = 0
vv_adi = vvcc[ivc]
aux_array = np.array(parts[ivc][ic])
print vv_adi

axes[0][0].plot([0,lsrs[ic][0]],[0,lsrs[ic][1]],ls="--",c='k',alpha=.5)
axes[0][0].plot(R0*np.cos(auxtt),R0*np.sin(auxtt),ls="--",c='k',alpha=.5)
axes[0][0].scatter(aux_array[:,0],aux_array[:,1],c="r",alpha=.5,s=8)
axes[0][0].scatter(aux_array[0,0],aux_array[0,1],c="r",alpha=1,s=40)
axes[0][0].quiver(aux_array[0:-1:15,0],aux_array[0:-1:15,1],\
                              aux_array[0:-1:15,3]*mt.C.kpc.express(mt.C.km),\
                              aux_array[0:-1:15,4]*mt.C.kpc.express(mt.C.km),\
                              angles='xy', units='width', scale=2000,color="k",alpha=.8)
axes[0][0].quiver(lsrs[ic][0],lsrs[ic][1],\
                              lsrs[ic][3]*mt.C.kpc.express(mt.C.km),\
                              lsrs[ic][4]*mt.C.kpc.express(mt.C.km),\
                              angles='xy', units='width', scale=2000,color="r",alpha=1)
axes[0][0].set_xlim(lsrs[ic][0]-2,lsrs[ic][0]+1)
axes[0][0].set_ylim(lsrs[ic][1]-1.5,lsrs[ic][1]+1.5)
axes[0][0].set_xlabel("$X$ [kpc]")
axes[0][0].set_ylabel("$Y$ [kpc]")
axes[0][0].set_aspect('equal')
axes[0][0].minorticks_on()

r_LSR = np.array(lsrs[ic][:3:])
v_LSR = np.array(lsrs[ic][3::])
cc = np.array([xv[:3:] for xv in aux_array])
vv = np.array([xv[3::] for xv in aux_array])
vv_galac = np.array([oc.vcart2vgalactic(cc[k],r_LSR,vv[k],v_LSR)*mt.C.kpc.express(mt.C.km) for k in range(len(vv))])
cc_galac = np.array([oc.cart2galactic(c,r_LSR) for c in cc])
axes[0][1].scatter(cc_galac[:,0]*np.cos(cc_galac[:,1]),cc_galac[:,0]*np.sin(cc_galac[:,1]),c="r",alpha=.5,s=8)
axes[0][1].plot([0,10],[0,0],ls="--",c='k',alpha=.5)
axes[0][1].scatter(cc_galac[0,0]*np.cos(cc_galac[0,1]),cc_galac[0,0]*np.sin(cc_galac[0,1]),alpha=1,s=40,c="r")
axes[0][1].quiver(cc_galac[0:-1:15,0]*np.cos(cc_galac[0:-1:15,1]),\
                  cc_galac[0:-1:15,0]*np.sin(cc_galac[0:-1:15,1]),\
                  vv_galac[0:-1:15,0]*np.cos(cc_galac[0:-1:15,1])-vv_galac[0:-1:15,1]*np.sin(cc_galac[0:-1:15,1]),\
                  vv_galac[0:-1:15,0]*np.sin(cc_galac[0:-1:15,1])+vv_galac[0:-1:15,1]*np.cos(cc_galac[0:-1:15,1]),\
                  angles='xy', units='width', scale=100,color="k",alpha=1)
axes[0][1].set_xlim(-2*.4,2*.4)
axes[0][1].set_ylim(-2*.4,2*.4)
axes[0][1].set_xlabel("$x$ [kpc]")
axes[0][1].set_ylabel("$y$ [kpc]")
axes[0][1].set_aspect('equal')

ic = 8
aux_array = np.array(parts[ivc][ic])

axes[1][0].plot([0,lsrs[ic][0]],[0,lsrs[ic][1]],ls="--",c='k',alpha=.5)
axes[1][0].plot(R0*np.cos(auxtt),R0*np.sin(auxtt),ls="--",c='k',alpha=.5)
axes[1][0].scatter(aux_array[:,0],aux_array[:,1],c="r",alpha=.5,s=8)
axes[1][0].scatter(aux_array[0,0],aux_array[0,1],c="r",alpha=1,s=40)
axes[1][0].quiver(aux_array[0:-1:15,0],aux_array[0:-1:15,1],\
                              aux_array[0:-1:15,3]*mt.C.kpc.express(mt.C.km),\
                              aux_array[0:-1:15,4]*mt.C.kpc.express(mt.C.km),\
                              angles='xy', units='width', scale=2000,color="k",alpha=.8)
axes[1][0].quiver(lsrs[ic][0],lsrs[ic][1],\
                              lsrs[ic][3]*mt.C.kpc.express(mt.C.km),\
                              lsrs[ic][4]*mt.C.kpc.express(mt.C.km),\
                              angles='xy', units='width', scale=2000,color="r",alpha=1)
axes[1][0].set_xlim(lsrs[ic][0]-2,lsrs[ic][0]+1)
axes[1][0].set_ylim(lsrs[ic][1]-1.5,lsrs[ic][1]+1.5)
axes[1][0].set_xlabel("$X$ [kpc]")
axes[1][0].set_ylabel("$Y$ [kpc]")
axes[1][0].set_aspect('equal')
axes[1][0].minorticks_on()

r_LSR = np.array(lsrs[ic][:3:])
v_LSR = np.array(lsrs[ic][3::])
cc = np.array([xv[:3:] for xv in aux_array])
vv = np.array([xv[3::] for xv in aux_array])
vv_galac = np.array([oc.vcart2vgalactic(cc[k],r_LSR,vv[k],v_LSR)*mt.C.kpc.express(mt.C.km) for k in range(len(vv))])
cc_galac = np.array([oc.cart2galactic(c,r_LSR) for c in cc])
axes[1][1].scatter(cc_galac[:,0]*np.cos(cc_galac[:,1]),cc_galac[:,0]*np.sin(cc_galac[:,1]),c="r",alpha=.5,s=8)
axes[1][1].plot([0,10],[0,0],ls="--",c='k',alpha=.5)
axes[1][1].scatter(cc_galac[0,0]*np.cos(cc_galac[0,1]),cc_galac[0,0]*np.sin(cc_galac[0,1]),alpha=1,s=40,c="r")
axes[1][1].quiver(cc_galac[0:-1:15,0]*np.cos(cc_galac[0:-1:15,1]),\
                  cc_galac[0:-1:15,0]*np.sin(cc_galac[0:-1:15,1]),\
                  vv_galac[0:-1:15,0]*np.cos(cc_galac[0:-1:15,1])-vv_galac[0:-1:15,1]*np.sin(cc_galac[0:-1:15,1]),\
                  vv_galac[0:-1:15,0]*np.sin(cc_galac[0:-1:15,1])+vv_galac[0:-1:15,1]*np.cos(cc_galac[0:-1:15,1]),\
                  angles='xy', units='width', scale=100,color="k",alpha=1)
axes[1][1].set_xlim(-2*.4,2*.4)
axes[1][1].set_ylim(-2*.4,2*.4)
axes[1][1].set_xlabel("$x$ [kpc]")
axes[1][1].set_ylabel("$y$ [kpc]")
axes[1][1].set_aspect('equal')

fig.tight_layout(w_pad=4,h_pad=-3)
fig.show()
#fig.savefig('AvsB.pdf')
# Out:
# [6. 0.]

# %%
len(vvcc)
# Out:
# 81

# %% [markdown]
# vvcct = [[oc.MCMCfit(parts[ivc][ic],lsrs[ic]) for ic in range(11)] for ivc in range(81)]
# np.save('/fs/nas14/other0/cbenitez/evolsOC/MCMCruns/oovvt_EXPvsROT',oovvt)

# %%
ivc = 76
vc = vvcc[ivc]
'/fs/nas14/other0/cbenitez/evolsOC/MCMCruns/vvcct_EXPvsROT_'+\
        str(np.round(vc[0],decimals=2))+"x"+\
        str(np.round(vc[1],decimals=2))
# Out:
# '/fs/nas14/other0/cbenitez/evolsOC/MCMCruns/vvcct_EXPvsROT_6.0x0.0'

# %%
ivc = 76
vc = vvcc[ivc]
vvcct = [oc.MCMCfit(parts[ivc][ic],lsrs[ic]) for ic in range(11)]

# %%
np.save('/fs/nas14/other0/cbenitez/evolsOC/MCMCruns/vvcct_EXPvsROT_'+\
        str(np.round(vc[0],decimals=2))+"x"+\
        str(np.round(vc[1],decimals=2)),vvcct)

# %%
vvcct = np.load('/fs/nas14/other0/cbenitez/evolsOC/MCMCruns/vvcct_EXPvsROT_6.0x0.0.npy')

# %%
[vvcct[i].flag_conv for i in range(len(vvcct))]
# Out:
# [True, True, True, True, True, True, True, True, True, True, True]

# %%
[np.array(vvcct[i].theta) for i in range(len(vvcct))]
# Out:
# [array([ 1.35479031e+01, -1.39399214e+01, -2.06750489e-03,  1.49984661e+01]),
#  array([ 12.88054145, -13.24732634,   0.02918788,  14.62044694]),
#  array([ 12.26809807, -12.61286621,   0.11961317,  14.26164469]),
#  array([ 11.69988993, -12.01326305,   0.25980652,  13.91700944]),
#  array([ 11.19131305, -11.45919612,   0.43604088,  13.58159595]),
#  array([ 10.74246481, -10.94255093,   0.65404042,  13.26763352]),
#  array([ 10.33913393, -10.46739993,   0.89854844,  12.95869171]),
#  array([  9.99038256, -10.00929801,   1.17473225,  12.6649383 ]),
#  array([ 9.68737966, -9.59130611,  1.46522713, 12.37387194]),
#  array([ 9.43913651, -9.19718125,  1.76968536, 12.08475751]),
#  array([ 9.23736016, -8.82539069,  2.08761741, 11.80665746])]

# %%
oc.plot_corner(vvcct[-1].sampler)

# %%
oc.plot_walks(vvcct[-1].sampler,vvcct[-1].burn_in*5)

# %%
oc.plot_fit(vvcct[10])
# Out:
# (<Figure size 1152x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3de80a1950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3de017d210>],
#        dtype=object))

# %%
plt.scatter(vvcct[10].cc_galac[:,1]*180/np.pi,vvcct[10].vv_galac[:,1]/vvcct[10].cc_galac[:,0])

# %%
plt.scatter(vvcct[10].cc_galac[:,1]*180/np.pi,vvcct[10].cc_galac[:,0])
plt.vlines(-90,.4,.6)
plt.vlines(90,.4,.6)

# %%
plt.figure(figsize=(5,5))
plt.scatter(vvcct[10].cc_galac[:,0]*np.cos(vvcct[10].cc_galac[:,1]),\
            vvcct[10].cc_galac[:,0]*np.sin(vvcct[10].cc_galac[:,1]))

# %%
vvcct[10].theta
# Out:
# [9.237360158617621, -8.825390690583609, 2.0876174095706657, 11.806657459294154]

# %%
#plt.plot(oocct[10].cc_galac[:,1],[oc.vell_model([1.,l,0],oocct[10].theta) for l in oocct[10].cc_galac[:,1]])
plt.plot(vvcct[10].cc_galac[:,1],[vvcct[10].theta[1]+vvcct[10].theta[0]*np.cos(2*l)-vvcct[10].theta[2]*np.sin(2*l) for l in vvcct[10].cc_galac[:,1]])
#plt.plot(vvcct[10].cc_galac[:,1],[vvcct[10].theta[1]+vvcct[10].theta[0]*np.cos(2*l)-vvcct[10].theta[2]*np.sin(2*l) for l in vvcct[10].cc_galac[:,1]])
plt.scatter(vvcct[10].cc_galac[:,1],vvcct[10].vv_galac[:,1]/vvcct[10].cc_galac[:,0],s=4)
plt.grid(True)

# %%
tt = [0.0199009793340327*2.65860467535e+15*mt.C.s.express(mt.C.Myr)*ti for ti in range(11)]

# %%
vvcct[0].theta
# Out:
# [13.54790309990582,
#  -13.939921413134458,
#  -0.0020675048873053095,
#  14.99846610654136]

# %%
plt.figure(figsize=(5,5))
for ioc in range(4):
    plt.plot(tt,[vvcct[ic].theta[ioc] for ic in range(11)])
    plt.scatter(tt,[vvcct[ic].theta[ioc] for ic in range(11)])    
plt.show()

# %%
Ai,Bi,Ci,Ki = oocct[0].theta

# %%
Ai,Bi,Ci,Ki
# Out:
# (13.548698928319046,
#  -13.936310461221911,
#  0.00445957250469419,
#  5.750046700977569)

# %%
alphas = np.arctan2(np.array(lsrs)[:,1],np.array(lsrs)[:,0])

# %%
alphas
# Out:
# array([ 0.        , -0.04713469, -0.09426938, -0.14140408, -0.18853877,
#        -0.23567346, -0.28280815, -0.32994284, -0.37707753, -0.42421223,
#        -0.47134692])

# %%
Ap = Ai*np.cos(2*alphas)-Ci*np.sin(2*alphas)
Cp = Ai*np.sin(2*alphas)+Ci*np.cos(2*alphas)

# %%
plt.figure(figsize=(5,5))
for ioc in range(4):
    plt.plot(tt,[oocct[ic].theta[ioc] for ic in range(11)])
    plt.scatter(tt,[oocct[ic].theta[ioc] for ic in range(11)])    
plt.plot(tt,Ap)
plt.plot(tt,Cp)
plt.show()

# %%
alphas
# Out:
# array([ 0.        , -0.04713469, -0.09426938, -0.14140408, -0.18853877,
#        -0.23567346, -0.28280815, -0.32994284, -0.37707753, -0.42421223,
#        -0.47134692])
